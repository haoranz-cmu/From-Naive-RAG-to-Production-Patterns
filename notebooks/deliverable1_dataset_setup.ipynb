# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset

# %% [markdown]
# # Training Dataset

# %%
ds = load_dataset("rag-datasets/rag-mini-wikipedia", "text-corpus")
print(ds)
# Out:
# DatasetDict({
#     passages: Dataset({
#         features: ['passage', 'id'],
#         num_rows: 3200
#     })
# })

# %%
for subset_name, subset in ds.items():
    print(f"Subset: {subset_name}")
    print(f"Number of examples: {len(subset)}")
    print(f"First example: {subset[0]}")
    print("\n")
# Out:
# Subset: passages
# Number of examples: 3200
# First example: {'passage': 'Uruguay (official full name in  ; pron.  , Eastern Republic of  Uruguay) is a country located in the southeastern part of South America.  It is home to 3.3 million people, of which 1.7 million live in the capital Montevideo and its metropolitan area.', 'id': 0}

# %%
# Convert to DataFrame for analysis
df_train = pd.DataFrame(subset)

# Basic dataset information
print("=== Training Dataset Basic Information ===")
print(f"Dataset name: rag-datasets/rag-mini-wikipedia (text-corpus)")
print(f"Dataset type: {type(ds)}")
print(f"Number of subsets: {len(ds)}")
print(f"Subset names: {list(ds.keys())}")

print(f"\n=== Training Dataset Details ===")
print(f"Subset: {subset_name}")
print(f"Number of examples: {len(subset)}")
print(f"Features: {subset.features}")
print(f"Data type: {type(subset)}")

# Display first few examples
print(f"\n=== Sample Training Examples ===")
for i in range(min(5, len(subset))):
    sample = subset[i]
    print(f"\nExample {i+1}:")
    print(f"  ID: {sample['id']}")
    print(f"  Passage: {sample['passage'][:200]}...")  # Show first 200 characters
# Out:
# === Training Dataset Basic Information ===
# Dataset name: rag-datasets/rag-mini-wikipedia (text-corpus)
# Dataset type: <class 'datasets.dataset_dict.DatasetDict'>
# Number of subsets: 1
# Subset names: ['passages']
#
# === Training Dataset Details ===
# Subset: passages
# Number of examples: 3200
# Features: {'passage': Value('string'), 'id': Value('int64')}
# Data type: <class 'datasets.arrow_dataset.Dataset'>
#
# === Sample Training Examples ===
#
# Example 1:
#   ID: 0
#   Passage: Uruguay (official full name in  ; pron.  , Eastern Republic of  Uruguay) is a country located in the southeastern part of South America.  It is home to 3.3 million people, of which 1.7 million live in...
#
# Example 2:
#   ID: 1
#   Passage: It is bordered by Brazil to the north, by Argentina across the bank of both the Uruguay River to the west and the estuary of RÃ­o de la Plata to the southwest, and the South Atlantic Ocean to the sout...
#
# Example 3:
#   ID: 2
#   Passage: Montevideo was founded by the Spanish in the early 18th century as a military stronghold. Uruguay won its independence in 1828 following a three-way struggle between Spain, Argentina and Brazil. It is...
#
# Example 4:
#   ID: 3
#   Passage: The economy is largely based in agriculture (making up 10% of the GDP and the most substantial export) and the state-sector, and relies heavily on world trade. Consequently, it is badly affected by an...
#
# Example 5:
#   ID: 4
#   Passage: According to Transparency International, Uruguay is the second least corrupt country in Latin America (after Chile),  Transparency.org.  with its political and labor conditions being among the freest ...

# %%
# Training Dataset Quality Analysis
print("=== Training Dataset Quality Analysis ===")

# Basic statistics
print(f"\n1. Basic Statistics:")
print(f"   Total samples: {len(df_train)}")
print(f"   Number of columns: {len(df_train.columns)}")
print(f"   Column names: {list(df_train.columns)}")

# Missing values check
print(f"\n2. Missing Values Check:")
missing_values = df_train.isnull().sum()
print(f"   Missing values:")
for col in df_train.columns:
    print(f"     {col}: {missing_values[col]} ({missing_values[col]/len(df_train)*100:.2f}%)")

# Data types
print(f"\n3. Data Types:")
print(f"   {df_train.dtypes}")

# Duplicate values check
print(f"\n4. Duplicate Values Check:")
duplicates = df_train.duplicated().sum()
print(f"   Duplicate rows: {duplicates} ({duplicates/len(df_train)*100:.2f}%)")

# ID analysis
print(f"\n5. ID Analysis:")
print(f"   ID unique values: {df_train['id'].nunique()}")
print(f"   ID range: {df_train['id'].min()} - {df_train['id'].max()}")
print(f"   ID continuous: {df_train['id'].is_monotonic_increasing}")

# Passage length analysis
print(f"\n6. Passage Length Analysis:")
df_train['passage_length'] = df_train['passage'].str.len()
passage_length_stats = df_train['passage_length'].describe()
print(f"   Passage length statistics:")
print(f"   {passage_length_stats}")

print(f"\n   Passage length range: {df_train['passage_length'].min()}-{df_train['passage_length'].max()} characters")
print(f"   Average passage length: {df_train['passage_length'].mean():.2f} characters")
# Out:
# === Training Dataset Quality Analysis ===
#
# 1. Basic Statistics:
#    Total samples: 3200
#    Number of columns: 2
#    Column names: ['passage', 'id']
#
# 2. Missing Values Check:
#    Missing values:
#      passage: 0 (0.00%)
#      id: 0 (0.00%)
#
# 3. Data Types:
#    passage    object
# id          int64
# dtype: object
#
# 4. Duplicate Values Check:
#    Duplicate rows: 0 (0.00%)
#
# 5. ID Analysis:
#    ID unique values: 3200
#    ID range: 0 - 3200
#    ID continuous: True
#
# 6. Passage Length Analysis:
#    Passage length statistics:
#    count    3200.000000
# mean      389.848125
# std       348.368869
# min         1.000000
# 25%       108.000000
# 50%       299.000000
# 75%       574.000000
# max      2515.000000
# Name: passage_length, dtype: float64
#
#    Passage length range: 1-2515 characters
#    Average passage length: 389.85 characters

# %%
# Training Dataset Visualization
print("=== Training Dataset Visualization ===")

# Create visualizations
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Training Dataset Analysis Visualization', fontsize=16, fontweight='bold')

# 1. Passage Length Distribution
axes[0, 0].hist(df_train['passage_length'], bins=50, alpha=0.7, color='skyblue', edgecolor='black')
axes[0, 0].set_title('Passage Length Distribution')
axes[0, 0].set_xlabel('Number of Characters')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].grid(True, alpha=0.3)

# 2. Passage Length Box Plot
axes[0, 1].boxplot(df_train['passage_length'], vert=True)
axes[0, 1].set_title('Passage Length Box Plot')
axes[0, 1].set_ylabel('Number of Characters')
axes[0, 1].grid(True, alpha=0.3)

# 3. ID vs Passage Length
axes[1, 0].scatter(df_train['id'], df_train['passage_length'], alpha=0.6, s=1)
axes[1, 0].set_title('Passage Length vs ID')
axes[1, 0].set_xlabel('ID')
axes[1, 0].set_ylabel('Passage Length (characters)')
axes[1, 0].grid(True, alpha=0.3)

# 4. Passage Length Cumulative Distribution
import numpy as np
sorted_lengths = np.sort(df_train['passage_length'])
cumulative = np.arange(1, len(sorted_lengths) + 1) / len(sorted_lengths)
axes[1, 1].plot(sorted_lengths, cumulative, linewidth=2)
axes[1, 1].set_title('Passage Length Cumulative Distribution')
axes[1, 1].set_xlabel('Number of Characters')
axes[1, 1].set_ylabel('Cumulative Probability')
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Data Quality Summary
print(f"\n=== Training Dataset Quality Summary ===")
print(f"✓ Dataset completeness: No missing values")
print(f"✓ Data uniqueness: No duplicate rows")
print(f"✓ ID continuity: {'Yes' if df_train['id'].is_monotonic_increasing else 'No'}")
print(f"✓ Passage length range: {df_train['passage_length'].min()}-{df_train['passage_length'].max()} characters")
print(f"✓ Average passage length: {df_train['passage_length'].mean():.2f} characters")
print(f"✓ Dataset size: {len(df_train)} passages")
print(f"✓ Memory usage: {df_train.memory_usage(deep=True).sum() / 1024 / 1024:.2f} MB")
# Out:
# === Training Dataset Visualization ===
# === Training Dataset Quality Summary ===
# ✓ Dataset completeness: No missing values
# ✓ Data uniqueness: No duplicate rows
# ✓ ID continuity: Yes
# ✓ Passage length range: 1-2515 characters
# ✓ Average passage length: 389.85 characters
# ✓ Dataset size: 3200 passages
# ✓ Memory usage: 1.72 MB

# %%
df_train.to_csv("../data/training-rag-mini-wikipedia_question-answer.csv")

# %% [markdown]
# # Test Dataset

# %%
ds = load_dataset("rag-datasets/rag-mini-wikipedia", "question-answer")
print(ds)
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['question', 'answer', 'id'],
#         num_rows: 918
#     })
# })

# %%
for subset_name, subset in ds.items():
    print(f"Subset: {subset_name}")
    print(f"Number of examples: {len(subset)}")
    print(f"First example: {subset[0]}")
    print("\n")
# Out:
# Subset: test
# Number of examples: 918
# First example: {'question': 'Was Abraham Lincoln the sixteenth President of the United States?', 'answer': 'yes', 'id': 0}

# %%
subset_name, subset = next(iter(ds.items()))

df = pd.DataFrame(subset)

# %%
df.head()
# Out:
#                                             question     answer  id
# 0  Was Abraham Lincoln the sixteenth President of...        yes   0
# 1  Did Lincoln sign the National Banking Act of 1...        yes   2
# 2                   Did his mother die of pneumonia?         no   4
# 3      How many long was Lincoln's formal education?  18 months   6
# 4       When did Lincoln begin his political career?       1832   8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  918 non-null    object
#  1   answer    918 non-null    object
#  2   id        918 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 21.6+ KB

# %%
df.describe()
# Out:
#                id
# count   918.00000
# mean    923.61329
# std     484.11148
# min       0.00000
# 25%     503.50000
# 50%     956.00000
# 75%    1334.50000
# max    1714.00000

# %%
# test if there are missing values
df.isnull().sum()
# Out:
# question    0
# answer      0
# id          0
# dtype: int64

# %%
# test if there are duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# test if the id is unique
df["id"].nunique() == len(df)
# Out:
# True

# %%
print(f"   ID range: {df['id'].min()} - {df['id'].max()}")
print(f"   ID continuous: {df['id'].is_monotonic_increasing}")
# Out:
#    ID range: 0 - 1714
#    ID continuous: True

# %%
# Question Uniqueness Analysis
print("=== Question Uniqueness Analysis ===")
unique_questions = df['question'].nunique()
total_questions = len(df)
print(f"Unique questions: {unique_questions}")
print(f"Total questions: {total_questions}")
print(f"Duplicate questions: {total_questions - unique_questions}")
print(f"Duplication rate: {(total_questions - unique_questions)/total_questions*100:.2f}%")

# Question Length Statistics
print(f"\nQuestion Length Statistics:")
question_length_stats = df['question'].apply(len).describe()
print(question_length_stats)

# Question Length Distribution Histogram
plt.figure(figsize=(10, 6))
df['question'].apply(len).hist(bins=30, edgecolor='black', alpha=0.7)
plt.title('Question Length Distribution')
plt.xlabel('Number of Characters')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# Duplicate Questions Analysis
print(f"\nDuplicate Questions Analysis:")
duplicate_questions = df['question'].value_counts()
duplicate_questions = duplicate_questions[duplicate_questions > 1]
print(f"Number of questions with duplicates: {len(duplicate_questions)}")

if len(duplicate_questions) > 0:
    print(f"\nMost frequently duplicated questions:")
    for question, count in duplicate_questions.head(10).items():
        print(f"     '{question}': {count} ({count/len(df)*100:.2f}%)")
else:
    print("     ✓ All questions are unique")

# Answer Distribution Analysis
print(f"\n=== Answer Distribution Analysis ===")
answer_counts = df['answer'].value_counts()
print(f"Number of answer categories: {len(answer_counts)}")
print(f"Answer distribution:")
for answer, count in answer_counts.items():
    print(f"     '{answer}': {count} ({count/len(df)*100:.2f}%)")
# Out:
# === Question Uniqueness Analysis ===
# Unique questions: 918
# Total questions: 918
# Duplicate questions: 0
# Duplication rate: 0.00%
#
# Question Length Statistics:
# count    918.000000
# mean      53.090414
# std       28.482015
# min        4.000000
# 25%       36.000000
# 50%       47.000000
# 75%       61.000000
# max      252.000000
# Name: question, dtype: float64
# Duplicate Questions Analysis:
# Number of questions with duplicates: 0
#      ✓ All questions are unique
#
# === Answer Distribution Analysis ===
# Number of answer categories: 499
# Answer distribution:
#      'yes': 160 (17.43%)
#      'Yes': 133 (14.49%)
#      'Yes.': 39 (4.25%)
#      'no': 34 (3.70%)
#      'No': 25 (2.72%)
#      'No.': 16 (1.74%)
#      'Grant': 3 (0.33%)
#      'John Adams': 3 (0.33%)
#      '75 years': 2 (0.22%)
#      'Japan': 2 (0.22%)
#      'loons or divers, grebes, gallinules, and coots': 2 (0.22%)
#      'millard fillmore': 2 (0.22%)
#      'His father': 2 (0.22%)
#      'Grover Cleveland': 2 (0.22%)
#      'Amedeo Avogadro': 2 (0.22%)
#      'Anders Celsius': 2 (0.22%)
#      '1846': 2 (0.22%)
#      'Pleurodira': 2 (0.22%)
#      'hopping': 2 (0.22%)
#      '1776': 2 (0.22%)
#      'roo bars': 2 (0.22%)
#      'The Federalist Party': 2 (0.22%)
#      'Poaching, habitat loss, and toxins in gold mining.  ': 1 (0.11%)
#      'Otters': 1 (0.11%)
#      'The time of year associated with this is also associated with the Aquarius sign of the Zodiac, through which the sun passes January 20-February 19. ': 1 (0.11%)
#      'Penguins': 1 (0.11%)
#      'It conserves energy while moving quickly': 1 (0.11%)
#      'Fish.': 1 (0.11%)
#      'Their wings have become flippers': 1 (0.11%)
#      '1.80 meters': 1 (0.11%)
#      'Sphenisciformes': 1 (0.11%)
#      'The slide down snowy slopes, apparently for sheer enjoyment.  ': 1 (0.11%)
#      'they have brown rather than black plumage': 1 (0.11%)
#      'between 17 and 20 living species': 1 (0.11%)
#      'half of their life': 1 (0.11%)
#      'for camouflage': 1 (0.11%)
#      'weasels, polecats, and badgers': 1 (0.11%)
#      'Emperor Penguin': 1 (0.11%)
#      'Shellfish and other invertebrates': 1 (0.11%)
#      'Holt': 1 (0.11%)
#      'A layer of air trapped in their fur.  ': 1 (0.11%)
#      'A holt': 1 (0.11%)
#      'Long guard hair': 1 (0.11%)
#      'when penguins slide on their bellies across the snow': 1 (0.11%)
#      'It is not even known.': 1 (0.11%)
#      '3 meters': 1 (0.11%)
#      'They gain double their weight.': 1 (0.11%)
#      'baladiyah.': 1 (0.11%)
#      'At the Doha Players Theatre.': 1 (0.11%)
#      'Doha.': 1 (0.11%)
#      'September 3, 1971.': 1 (0.11%)
#      'They sometimes have problems with various skin diseases with dermatitis caused sometimes by mites or other parasites.': 1 (0.11%)
#      'Garbage is now recycled or transported to Thompson, Manitoba.': 1 (0.11%)
#      'It has adapted for life on a combination of land, sea, and ice.': 1 (0.11%)
#      'It is arguable.': 1 (0.11%)
#      'They filed lawsuits in California.': 1 (0.11%)
#      'Database entry.': 1 (0.11%)
#      'Its think blubber and fur.': 1 (0.11%)
#      'A polar bear's skin.': 1 (0.11%)
#      'Polar bears are nearly invisible under infrared photography.': 1 (0.11%)
#      'It provides the animal with effective camouflage.': 1 (0.11%)
#      'Penguins' wings': 1 (0.11%)
#      '1002 kg (2200 lb) ': 1 (0.11%)
#      '300-600 kg (660-1320 lb)': 1 (0.11%)
#      'The polar bear diverged from the brown bear about 200 thousand years ago.': 1 (0.11%)
#      'The World Conservation Union listed polar bears as a vulnerable species, one of three sub-categories of threatened status, in May 2006. Their latest estimate is that 7 out of 19 subpopulations are declining or already severely reduced.': 1 (0.11%)
#      'mites or other parasites': 1 (0.11%)
#      '5-15 cm': 1 (0.11%)
#      'white or cream': 1 (0.11%)
#      '2200 lb': 1 (0.11%)
#      'Connecticut': 1 (0.11%)
#      'At least one giant penguin.': 1 (0.11%)
#      'give birth': 1 (0.11%)
#      'In the water they are.': 1 (0.11%)
#      'They sometimes attempt to "steal" another chick.': 1 (0.11%)
#      'Humans hunted them almost to extinction. ': 1 (0.11%)
#      '13': 1 (0.11%)
#      'The word "otter" derives from the Old English word otr, otor or oter. ': 1 (0.11%)
#      'Felis pardus': 1 (0.11%)
#      'Raetia.': 1 (0.11%)
#      'Switzerland and Austria.': 1 (0.11%)
#      'German.': 1 (0.11%)
#      'October 1921.': 1 (0.11%)
#      'two-thirds': 1 (0.11%)
#      'Austrian Federal Railways': 1 (0.11%)
#      'Swiss franc': 1 (0.11%)
#      '11': 1 (0.11%)
#      '1836': 1 (0.11%)
#      'One of the many species described in Linnaeus's 18th-century work, Systema Naturae': 1 (0.11%)
#      'The leopard men': 1 (0.11%)
#      'Leopards': 1 (0.11%)
#      'The leopard's ecological role': 1 (0.11%)
#      'Sea otters (Enhydra lutris) live along the Pacific coast of North America. ': 1 (0.11%)
#      'As of 1996, the leopard had the largest distribution of any wild cat, although populations before and since have shown a declining trend and are fragmented outside of subsaharan Africa.': 1 (0.11%)
#      'The leopard has roS08_settes rather than cheetah's simple spots and the leopard is larger and less lanky than the cheetah.': 1 (0.11%)
#      'Males are considerably larger than females and weigh 37 to 90 kg compared to 28 to 60 kg for females. ': 1 (0.11%)
#      '60 to 110cm': 1 (0.11%)
#      'southern Eurasia and Africa': 1 (0.11%)
#      'circular': 1 (0.11%)
#      'Black Panthers': 1 (0.11%)
#      'by the length of their tails': 1 (0.11%)
#      'in dense vegetation': 1 (0.11%)
#      'a pumapard': 1 (0.11%)
#      'A cheetah or a jaguar': 1 (0.11%)
#      'Changes wrought to the Australian landscape by humans.': 1 (0.11%)
#      '6.': 1 (0.11%)
#      'Liechtenstein': 1 (0.11%)
#      '1861': 1 (0.11%)
#      'Liechtenstein's population': 1 (0.11%)
#      '13 species and 7 genera': 1 (0.11%)
#      'roadkill deaths': 1 (0.11%)
#      'They've been hunted for their fur': 1 (0.11%)
#      'a layer of air trapped in their fur(!)': 1 (0.11%)
#      '30 kg (about 65 pounds)': 1 (0.11%)
#      'a variety of fish and shellfish, as well as small land mammals and birds': 1 (0.11%)
#      'The British Protectorate (per Colonel Lewis Pelly) asking to negotiate with a representative from Qatar after Bahrain's violation of the 1820 Anglo-Bahraini Treaty.': 1 (0.11%)
#      'yes.': 1 (0.11%)
#      'Nikola Tesla': 1 (0.11%)
#      'Fillmore was born': 1 (0.11%)
#      'they were ok with him': 1 (0.11%)
#      'upon the death of the sitting president, Taylor': 1 (0.11%)
#      'slavory issues': 1 (0.11%)
#      'He fell in love with Abigail Powers': 1 (0.11%)
#      'to Nathaniel and Phoebe Millard Fillmore': 1 (0.11%)
#      'in a log cabin in Summerhill, New York': 1 (0.11%)
#      'where is the death date of his first wife?': 1 (0.11%)
#      'Before.': 1 (0.11%)
#      'A fake biography based on real events that happened in Fillmore's life.': 1 (0.11%)
#      'Weed': 1 (0.11%)
#      'The Liechtenstein Dynasty acquired vast swaths of land': 1 (0.11%)
#      'a role in preserving the culture and history of the country.': 1 (0.11%)
#      'on the conformity of laws with the constitution': 1 (0.11%)
#      'the Kunstmuseum Liechtenstein': 1 (0.11%)
#      'They are Hilti.': 1 (0.11%)
#      'Carnegie Mellon University, Georgetown University School of Foreign Service, Texas A&M University, Virginia Commonwealth University, and Cornell University's Weill Medical College.': 1 (0.11%)
#      '41.': 1 (0.11%)
#      'On September 3, 1971.': 1 (0.11%)
#      '*shrug*': 1 (0.11%)
#      'European immigrants.': 1 (0.11%)
#      'San Carlos, Maldonado.': 1 (0.11%)
#      'The Spanish.': 1 (0.11%)
#      'his reputation as president has improved': 1 (0.11%)
#      'he accepted the surrender of Robert E. Lee': 1 (0.11%)
#      'they did': 1 (0.11%)
#      '1856': 1 (0.11%)
#      '1868': 1 (0.11%)
#      'He thought it was designed to gain land open to slavery.': 1 (0.11%)
#      'It went well.': 1 (0.11%)
#      'Republican': 1 (0.11%)
#      'Point Pleasant, Ohio': 1 (0.11%)
#      'Fred Dent': 1 (0.11%)
#      'spherical': 1 (0.11%)
#      'a rich blood supply': 1 (0.11%)
#      'all of them': 1 (0.11%)
#      'eggs': 1 (0.11%)
#      'Amniotes': 1 (0.11%)
#      'Mud or Sand': 1 (0.11%)
#      'Holes Dug into the Mud or Sand': 1 (0.11%)
#      'Yolk': 1 (0.11%)
#      'Paracryptodira': 1 (0.11%)
#      'Because of the way they withdraw their heads into their shells.': 1 (0.11%)
#      'Papillae': 1 (0.11%)
#      'A female turtle.': 1 (0.11%)
#      'Triassic, Ernst Haeckel, Kunstformen der Natur, Animal': 1 (0.11%)
#      'Russian Tortoises': 1 (0.11%)
#      'Cantegriles.': 1 (0.11%)
#      'None.': 1 (0.11%)
#      'Yes. It's located in the southeastern part': 1 (0.11%)
#      'Its independence': 1 (0.11%)
#      'Wilson': 1 (0.11%)
#      'Irish Americans': 1 (0.11%)
#      'His ancestry': 1 (0.11%)
#      'Woodrow Wilson was born in Staunton, Virginia': 1 (0.11%)
#      'Wilson attended law school at University of Virginia': 1 (0.11%)
#      'He was buried in Washington National Cathedral': 1 (0.11%)
#      'His confrontation with Andrew Fleming West': 1 (0.11%)
#      'German began unrestricted submarine warfare': 1 (0.11%)
#      'history and political science': 1 (0.11%)
#      'December 28, 1856': 1 (0.11%)
#      'Paris': 1 (0.11%)
#      'No?': 1 (0.11%)
#      'Uruguay exports architectural services to India and Latin America': 1 (0.11%)
#      'Yes. People are allowed to challenge laws.': 1 (0.11%)
#      '(What?)': 1 (0.11%)
#      'Montevideo': 1 (0.11%)
#      'Partido Colorado and Partido Blanco': 1 (0.11%)
#      'Labeling as "Natural" or "Ecological"': 1 (0.11%)
#      'Roman Catholic, Protestant, Jewish, and nonprofessing.': 1 (0.11%)
#      'Referendum': 1 (0.11%)
#      'African women earns 0.65 * 0.718  = 46.67% of a European man earns in average': 1 (0.11%)
#      'Twice. ': 1 (0.11%)
#      'For a military stronghold.': 1 (0.11%)
#      '88%': 1 (0.11%)
#      '176.215 km�� ': 1 (0.11%)
#      'Yes, in 1930.': 1 (0.11%)
#      'Three.': 1 (0.11%)
#      'They do not gradually break down or become less efficient over time': 1 (0.11%)
#      'Much of the country.': 1 (0.11%)
#      'They lay eggs': 1 (0.11%)
#      'Six days': 1 (0.11%)
#      'The government seeks to increase its GDP contribution to 3% by 2012. ': 1 (0.11%)
#      'Singapore has a tropical rainforest climate with no distinctive seasons.': 1 (0.11%)
#      'One of three heavy rail passenger transport lines in Singapore.': 1 (0.11%)
#      'Orang Laut people lived around the coast, rivers and smaller islands.': 1 (0.11%)
#      'More than 2.78 million people.': 1 (0.11%)
#      'No, it contributed 1.56% to GDP in 2001.': 1 (0.11%)
#      'No, the standard living was raised.': 1 (0.11%)
#      'Yes, they do.': 1 (0.11%)
#      'investments worth 400 million euros': 1 (0.11%)
#      '(not sure how to answer this)': 1 (0.11%)
#      'the remains (the lower jaw) of the oldest modern human': 1 (0.11%)
#      '2007': 1 (0.11%)
#      'it received a Soviet ultimatum': 1 (0.11%)
#      'Romania is a secular state': 1 (0.11%)
#      'eleven': 1 (0.11%)
#      'Hungarians': 1 (0.11%)
#      'Bucharest': 1 (0.11%)
#      'Nadia Comăneci': 1 (0.11%)
#      '2.': 1 (0.11%)
#      'Romanian.': 1 (0.11%)
#      'Moldoveanu Peak.': 1 (0.11%)
#      'Veterinarians': 1 (0.11%)
#      'These allophones cannot occur there.': 1 (0.11%)
#      'Qatar.': 1 (0.11%)
#      'Qatar': 1 (0.11%)
#      'Qatar is aiming to become a role model for economic and social transformation in the region. Large scale investment in all social and economic sectors will also lead to the development of a strong financial market.': 1 (0.11%)
#      'lion': 1 (0.11%)
#      'second century AD': 1 (0.11%)
#      'The British were defeated in six days': 1 (0.11%)
#      '28 East 20th Street in the modern-day Gramercy section of New York City': 1 (0.11%)
#      'air': 1 (0.11%)
#      'Every few years or more': 1 (0.11%)
#      'Spherical': 1 (0.11%)
#      'Financed by Andrew Carnegie and his own proposed writings': 1 (0.11%)
#      'On January 6, 1919, Roosevelt died in his sleep.': 1 (0.11%)
#      'Lincoln was Roosevelt's presidential hero.': 1 (0.11%)
#      'Gramercy section of New York City': 1 (0.11%)
#      'mixing of the races on social occassions': 1 (0.11%)
#      'Noting that his children had been educated with other races and there was nothing wrong with it': 1 (0.11%)
#      'Bamie as a child and Bye as an adult': 1 (0.11%)
#      'To deal with bullies': 1 (0.11%)
#      'Roosevelt took up exercise': 1 (0.11%)
#      'By 2001, there were 19 raw water reservoirs, 9 treatment works and 14 storage or service reservoirs locally to serve domestic needs. ': 1 (0.11%)
#      'In 1990, Goh Chok Tong succeeded Lee as Prime Minister.': 1 (0.11%)
#      'British India office': 1 (0.11%)
#      'Singapore': 1 (0.11%)
#      'British': 1 (0.11%)
#      'British East India Company ': 1 (0.11%)
#      'There are laws which allow capital punishment in Singapore for first-degree murder and drug trafficking.': 1 (0.11%)
#      '1959': 1 (0.11%)
#      'British East India Company': 1 (0.11%)
#      'Monaco': 1 (0.11%)
#      'Due to obvious geographical reasons, relations with Malaysia and Indonesia are most important.': 1 (0.11%)
#      'Singapore Botanic Gardens.': 1 (0.11%)
#      'The national language of Singapore is Malay.': 1 (0.11%)
#      'The primary domestic source of water supply in Singapore is rainfall.': 1 (0.11%)
#      'different diets': 1 (0.11%)
#      '4.6 years': 1 (0.11%)
#      'The Red Kangaroo, The Eastern Grey Kangaroo, The Western Grey Kangaroo, and The Antilopine Kangaroo': 1 (0.11%)
#      'Greater Helsinki': 1 (0.11%)
#      'Quacks like a duck': 1 (0.11%)
#      'Tiny rows of plates called lamellae': 1 (0.11%)
#      'Meat,eggs,feathers': 1 (0.11%)
#      'Their inability to fly.': 1 (0.11%)
#      'It's tongue is a flat plate, and on the tongue's back end is a short liftable flap with about 18 short spikes for pushing struggling prey and other food down its throat': 1 (0.11%)
#      'Pike, crocodilians, herons, hawks and eagles.': 1 (0.11%)
#      'It is the common name for a number of species in the Anatidae family of birds.': 1 (0.11%)
#      'Dabbling ducks': 1 (0.11%)
#      'They are farmed for their meat, eggs and feathers. They are also kept and bred by aviculturists and often displayed in zoos.': 1 (0.11%)
#      'Meat, eggs, and feathers': 1 (0.11%)
#      'They are heavier': 1 (0.11%)
#      'A silly cartoon character': 1 (0.11%)
#      'Meat': 1 (0.11%)
#      'The duck': 1 (0.11%)
#      'the smew': 1 (0.11%)
#      'Some are': 1 (0.11%)
#      'Canada was formed as a federal, semi-autonomous polity': 1 (0.11%)
#      'no!': 1 (0.11%)
#      'The first Canadian Army units in WW II': 1 (0.11%)
#      'The Maple Leaf Flag': 1 (0.11%)
#      'Canada maintains full relations with both.': 1 (0.11%)
#      'The fur trade': 1 (0.11%)
#      '1545': 1 (0.11%)
#      'The lands': 1 (0.11%)
#      '1944.': 1 (0.11%)
#      'According to 2001 census, 77.1% of Canadians identified as being Christians; of this, Catholics make up the largest group (43.6% of Canadians). The largest Protestant denomination is the United Church of Canada; about 16.5% of Canadians declare no religious affiliation, and the remaining 6.3% were affiliated with religions other than Christianity, of which the largest is Islam numbering 1.9%, followed by Judaism: 1.1%. ': 1 (0.11%)
#      'Canada is the second largest country in the world, after Russia, and largest on the continent.': 1 (0.11%)
#      'In many areas, wild duckof various species (including ducks farmed and released into the wild) are hunted for food or sport, by shooting, or formerly by decoys.': 1 (0.11%)
#      '1967': 1 (0.11%)
#      'All but Christianity, Islam, and Judaism': 1 (0.11%)
#      'by producing and receiving low frequency sound': 1 (0.11%)
#      'the Gulf of Finland': 1 (0.11%)
#      '1952': 1 (0.11%)
#      'Alexander I': 1 (0.11%)
#      'None, the elephant is the largest land animal.': 1 (0.11%)
#      'Angola': 1 (0.11%)
#      'Ears': 1 (0.11%)
#      '60000': 1 (0.11%)
#      'elephant': 1 (0.11%)
#      'temperature regulation': 1 (0.11%)
#      'three': 1 (0.11%)
#      '22 months': 1 (0.11%)
#      'when they are sick or wounded': 1 (0.11%)
#      'the beast which pasS08_seth all others in wit and mind': 1 (0.11%)
#      'more than 78 million': 1 (0.11%)
#      '120 kilograms': 1 (0.11%)
#      '1': 1 (0.11%)
#      'it refers literally to elephants supposedly having an excellent memory': 1 (0.11%)
#      '70 years': 1 (0.11%)
#      '2': 1 (0.11%)
#      '6000 BC.': 1 (0.11%)
#      'More than 78 million.': 1 (0.11%)
#      'Libya, Sudan, the Gaza Strip and Israel.': 1 (0.11%)
#      'During the Old Kingdom.': 1 (0.11%)
#      'June 18 1953.': 1 (0.11%)
#      'The New Kingdom (c.1550&#8722;1070 BC) ': 1 (0.11%)
#      'the only arable agricultural land is found there,': 1 (0.11%)
#      'The most densely populated part of the country is the Quebec City-Windsor Corridor along the Great Lakes and Saint Lawrence River in the southeast.': 1 (0.11%)
#      'While as of October 2007, Canada's national unemployment rate of 5.9% is its lowest in 33 years. Provincial unemployment rates vary from a low of 3.6% in Alberta to a high of 14.6% in Newfoundland and Labrador. ': 1 (0.11%)
#      'A federation now comprising ten provinces and three territories': 1 (0.11%)
#      '1820': 1 (0.11%)
#      'their hardened, often darkened head, the presence of chewing mouthparts, and spiracles along the sides of the body': 1 (0.11%)
#      'Colorado potato beetle': 1 (0.11%)
#      'mimicry': 1 (0.11%)
#      'the head, the thorax, and the abdomen': 1 (0.11%)
#      'The scale was reversed': 1 (0.11%)
#      'He was professor of astronomy at Uppsala University': 1 (0.11%)
#      'Yes he did': 1 (0.11%)
#      'Yes it had': 1 (0.11%)
#      'named after him': 1 (0.11%)
#      '1733': 1 (0.11%)
#      'The Celsius crater on the Moon': 1 (0.11%)
#      'Avogadro had been recalled to Turin university': 1 (0.11%)
#      '1821': 1 (0.11%)
#      'mouthparts': 1 (0.11%)
#      'he defended William "Duff" Armstrong': 1 (0.11%)
#      '23 years': 1 (0.11%)
#      'seven': 1 (0.11%)
#      'To free slaves ': 1 (0.11%)
#      'General McClellan': 1 (0.11%)
#      'John Wilkes Booth': 1 (0.11%)
#      'March 4, 1861': 1 (0.11%)
#      'Hardin County': 1 (0.11%)
#      '11-year-old Grace Bedell': 1 (0.11%)
#      'the United States Note, the first paper currency in United States history': 1 (0.11%)
#      '1832': 1 (0.11%)
#      '18 months': 1 (0.11%)
#      'Some are generalists, eating both plants and animals. Other beetles are highly specialised in their diet.': 1 (0.11%)
#      '350,000': 1 (0.11%)
#      '28%': 1 (0.11%)
#      'Plymouth': 1 (0.11%)
#      'During the Suez Crisis of 1956, Lester B. Pearson eased tensions by proposing the inception of the United Nations Peacekeeping Force. Canada has since served in 50 peacekeeping missions, including every UN peacekeeping effort until 1989': 1 (0.11%)
#      'France and Britain.': 1 (0.11%)
#      'The British North America Act.': 1 (0.11%)
#      'Quebec City': 1 (0.11%)
#      'Chinese.': 1 (0.11%)
#      '1906 and 1908': 1 (0.11%)
#      'It was too expensive': 1 (0.11%)
#      'Grace Anna Goodhue': 1 (0.11%)
#      'Phi Gamma Delta': 1 (0.11%)
#      '1898': 1 (0.11%)
#      'heart attack': 1 (0.11%)
#      'Plymouth, Windsor County, Vermont': 1 (0.11%)
#      'July 4 1872': 1 (0.11%)
#      'during pairing': 1 (0.11%)
#      'Coolidge': 1 (0.11%)
#      'MassachuS08_setts': 1 (0.11%)
#      'Coolidge moved to Northampton, MassachuS08_setts': 1 (0.11%)
#      'the Roaring Twenties': 1 (0.11%)
#      '1905': 1 (0.11%)
#      'upon graduating from college': 1 (0.11%)
#      'They are food to beetles.': 1 (0.11%)
#      'One kind of gas obtained via a tracheal system.': 1 (0.11%)
#      'Antennae.': 1 (0.11%)
#      'The name "Coleoptera".': 1 (0.11%)
#      'Beetles.': 1 (0.11%)
#      'coleopterology': 1 (0.11%)
#      'Golden Eagle, Brown Bear, or Eurasian Lynx (Change imperative to interrogative)': 1 (0.11%)
#      'CMX': 1 (0.11%)
#      'Captain James Cook and naturalist Sir Joseph Banks': 1 (0.11%)
#      'a highly industrialised, free-market economy': 1 (0.11%)
#      'Monroe': 1 (0.11%)
#      'As a result, the two nations moved closer toward the War of 1812. ': 1 (0.11%)
#      'No letters survive in which he might have discussed his religious beliefs.': 1 (0.11%)
#      'His daughter Maria Hester Monroe Gouverneur': 1 (0.11%)
#      'December 2, 1823': 1 (0.11%)
#      'Monroe Hill on the grounds of the University of Virginia.': 1 (0.11%)
#      'Monroe was elected president in the election of 1816, and re-elected in 1820.': 1 (0.11%)
#      'July 4, 1831': 1 (0.11%)
#      '1814': 1 (0.11%)
#      'George Washington': 1 (0.11%)
#      '1817-1825': 1 (0.11%)
#      'He practiced law in Virginia.': 1 (0.11%)
#      'Elizabeth Kortright': 1 (0.11%)
#      'at the Battle of Trenton, in his left shoulder': 1 (0.11%)
#      'Westmoreland County, Virginia': 1 (0.11%)
#      'A doctrine declaring U.S. opposition to European interference in the Americas.': 1 (0.11%)
#      'Reduced tension': 1 (0.11%)
#      'Maria Hester Monroe Gouverneur': 1 (0.11%)
#      'Spence': 1 (0.11%)
#      'March 4, 1825': 1 (0.11%)
#      '28': 1 (0.11%)
#      'James': 1 (0.11%)
#      'each province': 1 (0.11%)
#      'The indonesian archipelago became an important trade region': 1 (0.11%)
#      'the Javanese': 1 (0.11%)
#      'Indonesia': 1 (0.11%)
#      'Indonesia's special capital region': 1 (0.11%)
#      'two long tours': 1 (0.11%)
#      'Monroe's presidency': 1 (0.11%)
#      'many congressmen': 1 (0.11%)
#      'John Adams' birthplace': 1 (0.11%)
#      'a kangaroo': 1 (0.11%)
#      'a mob, troop, or court': 1 (0.11%)
#      'Thylacine, Marsupial Lion, Maagalania, and Wonambi': 1 (0.11%)
#      '1994': 1 (0.11%)
#      'bacteria': 1 (0.11%)
#      'The two sides of the lower jaw are not joined together and the lower incisors are farther apart.': 1 (0.11%)
#      'its hind feet': 1 (0.11%)
#      'marsupium': 1 (0.11%)
#      'mob, troop, or court': 1 (0.11%)
#      'Adams married Abigail Smith': 1 (0.11%)
#      'Democratic Republicans': 1 (0.11%)
#      'Adams's personal collection of more than 3,500 volumes': 1 (0.11%)
#      'Descriptions of events and ompressions of men': 1 (0.11%)
#      'Monroe returned to the Virginia House of Delegates and was elected to another term as governor of Virginia': 1 (0.11%)
#      'Hamilton wanted to control the army differently than Adams': 1 (0.11%)
#      'They were a series of judges, so called because most of them were formally appointed days before Adams' presidential term expired': 1 (0.11%)
#      'United First Parish Church': 1 (0.11%)
#      '1789-1797': 1 (0.11%)
#      'The Federalist Party.': 1 (0.11%)
#      'The "Colossus of Independence".': 1 (0.11%)
#      'Thomas Jefferson, Benjamin Franklin, Robert R. Livingston and Roger Sherman.': 1 (0.11%)
#      '1755.': 1 (0.11%)
#      'Watt began to experiment with steam after his friend, Professor John Robison, called his attention to it.': 1 (0.11%)
#      'Margaret Miller.': 1 (0.11%)
#      'Margaret Miller': 1 (0.11%)
#      'Monroe was elected president': 1 (0.11%)
#      'nutmeg, cloves, or cubeb pepper': 1 (0.11%)
#      'because of anti-communist purges early in the Suharto era': 1 (0.11%)
#      'the end of the 16th century': 1 (0.11%)
#      'Jay Berwanger': 1 (0.11%)
#      '500 miles north': 1 (0.11%)
#      'founder and first president': 1 (0.11%)
#      'warrior king': 1 (0.11%)
#      'Warm and comparatively dry': 1 (0.11%)
#      'Kwa and Gur': 1 (0.11%)
#      'Christian': 1 (0.11%)
#      'President John Agyekum Kofuor': 1 (0.11%)
#      '10': 1 (0.11%)
#      '1957': 1 (0.11%)
#      'They did claim Ford's pardon was quid pro quo.': 1 (0.11%)
#      'Ford received a commission as ensign in the US Naval Reserve.': 1 (0.11%)
#      'The Monterey supported landings at both locations.': 1 (0.11%)
#      '400': 1 (0.11%)
#      'The UK': 1 (0.11%)
#      'Michigan's 5th congressional district': 1 (0.11%)
#      'hard': 1 (0.11%)
#      'Bob Dole': 1 (0.11%)
#      'He was abusive and had a history of hitting his mother.': 1 (0.11%)
#      'Center and linebacker': 1 (0.11%)
#      'Over eight years.': 1 (0.11%)
#      'Finland is not involved in international conflicts or border disputes. ': 1 (0.11%)
#      'Christmas': 1 (0.11%)
#      'Helsinki': 1 (0.11%)
#      'Twelfth Century': 1 (0.11%)
#      'relatively warm': 1 (0.11%)
#      'Northern Europe': 1 (0.11%)
#      'the New Patriotic Party and National Democratic Congress': 1 (0.11%)
#      'bulky coats with two layers': 1 (0.11%)
#      '1999': 1 (0.11%)
#      'former Senator James G. Blaine of Maine': 1 (0.11%)
#      'the plate does not become clouded upon being exposed to the sun for a day': 1 (0.11%)
#      ' Becquerel accidentally discovered radioactivity.': 1 (0.11%)
#      'Yes he died at the age of 55': 1 (0.11%)
#      'Henri Becquerel': 1 (0.11%)
#      '1890': 1 (0.11%)
#      'phographic plates being fully exposed': 1 (0.11%)
#      'in 1894': 1 (0.11%)
#      '5': 1 (0.11%)
#      'Cleveland was born in Caldwell, New Jersey to the Reverend Richard Cleveland and Anne Neal.': 1 (0.11%)
#      '1884 and 1892 presidential elections': 1 (0.11%)
#      'June 24 1908': 1 (0.11%)
#      'To avoid further market panic': 1 (0.11%)
#      'That he had fathered an illegitimate child': 1 (0.11%)
#      'Helping the woldf to effectively navigate over large expanses while concurrently keeping others informed of its whereabouts.': 1 (0.11%)
#      'One Year': 1 (0.11%)
#      'A heart attack': 1 (0.11%)
#      'In the White House': 1 (0.11%)
#      'Dominance': 1 (0.11%)
#      'Darting and Foot hold traps.': 1 (0.11%)
#      'A pack can only suppport one littler per year': 1 (0.11%)
#      'Late Spring or Early Summer': 1 (0.11%)
#      'Canis': 1 (0.11%)
#      'Kazakhstan': 1 (0.11%)
#      'Surplus killing is defined as the killing of several prey animals too numerous to eat at one sitting.': 1 (0.11%)
#      'Howling helps pack members keep in touch, allowing them to communicate effectively in thickly forested areas or over great distances. Howling also helps to call pack members to a specific location. Howling can also serve as a declaration of territory, as shown in a dominant wolf&apos;s tendency to respond to a human imitation of a "rival" wolf in an area the wolf considers its own. ': 1 (0.11%)
#      'typically varies between 32 and 62 kilograms': 1 (0.11%)
#      'raised billions through Liberty loans, imposed an income tax, S08_set up the War Industries Board, promoted labor union growth, supervised agriculture and food production through the Lever Act, took over control of the railroads, and suppressed anti-war movements': 1 (0.11%)

# %%
# Answer Distribution Visualization
plt.figure(figsize=(12, 8))

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Answer Distribution Pie Chart
top_answers = answer_counts.head(10)  # Show top 10 most common answers
ax1.pie(top_answers.values, labels=top_answers.index, autopct='%1.1f%%', startangle=90)
ax1.set_title('Top 10 Most Common Answers Distribution')

# Answer Distribution Bar Chart
top_answers.plot(kind='bar', ax=ax2, color='skyblue', edgecolor='black')
ax2.set_title('Answer Frequency Distribution')
ax2.set_xlabel('Answer')
ax2.set_ylabel('Frequency')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Answer Length Analysis
print(f"\n=== Answer Length Analysis ===")
df['answer_length'] = df['answer'].apply(len)
answer_length_stats = df['answer_length'].describe()
print(f"Answer length statistics:")
print(answer_length_stats)

# Answer Length Distribution
plt.figure(figsize=(10, 6))
df['answer_length'].hist(bins=20, edgecolor='black', alpha=0.7, color='lightgreen')
plt.title('Answer Length Distribution')
plt.xlabel('Number of Characters')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# Data Quality Summary
print(f"\n=== Data Quality Summary ===")
print(f"✓ Dataset completeness: No missing values")
print(f"✓ Data uniqueness: No duplicate rows")
print(f"✓ Question uniqueness: {unique_questions}/{total_questions} ({unique_questions/total_questions*100:.2f}%)")
print(f"✓ Answer diversity: {len(answer_counts)} different answers")
print(f"✓ Question length range: {df['question'].apply(len).min()}-{df['question'].apply(len).max()} characters")
print(f"✓ Answer length range: {df['answer_length'].min()}-{df['answer_length'].max()} characters")
# Out:
# === Answer Length Analysis ===
# Answer length statistics:
# count    918.000000
# mean      19.183007
# std       34.959257
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%       21.000000
# max      423.000000
# Name: answer_length, dtype: float64
# === Data Quality Summary ===
# ✓ Dataset completeness: No missing values
# ✓ Data uniqueness: No duplicate rows
# ✓ Question uniqueness: 918/918 (100.00%)
# ✓ Answer diversity: 499 different answers
# ✓ Question length range: 4-252 characters
# ✓ Answer length range: 1-423 characters

# %%
df.to_csv("../data/test-rag-mini-wikipedia_question-answer.csv")
